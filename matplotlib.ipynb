# %% [markdown]
# # Matplotlib の練習

# %%
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
# (1,1) にプロット
plt.plot(1, 1, marker='.')
plt.xlim(0, 5)
plt.ylim(0, 5)
plt.title('タイトル')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
